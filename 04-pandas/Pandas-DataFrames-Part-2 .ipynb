# %% [markdown]
# # Working with Pandas DataFrames - Part 2

# %% [markdown]
# Last session we introduced Pandas. Now we review the basics of using Pandas, with a more interactive workflow using relevant data to solidify understanding and facility with this powerful Python toolkit.

# %% [markdown]
# ## Reviewing Pandas Basics

# %%
from pandas import DataFrame
import pandas as pd
import numpy as np

# %%
import pandas as pd
df = pd.read_csv('data/ca_tracts_pop_cleaned.csv')

# %% [markdown]
# ### A bit more practice with indexing in Pandas
#
# The first use of indexing is to use a slice, just like we have done with other Python objects. Below we slice the first 5 index values of the first dimension of the dataframe.

# %%
df[:5]
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
#
#                                       geodisplay  Population
# 0  Census Tract 4001, Alameda County, California        2937
# 1  Census Tract 4002, Alameda County, California        1974
# 2  Census Tract 4003, Alameda County, California        4865
# 3  Census Tract 4004, Alameda County, California        3703
# 4  Census Tract 4005, Alameda County, California        3517

# %% [markdown]
# The first indexing method is equivalent to usinf the iloc indexing method, which uses the integer based indexing, purely based on the location of the index.

# %%
df.iloc[:5]
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
#
#                                       geodisplay  Population
# 0  Census Tract 4001, Alameda County, California        2937
# 1  Census Tract 4002, Alameda County, California        1974
# 2  Census Tract 4003, Alameda County, California        4865
# 3  Census Tract 4004, Alameda County, California        3703
# 4  Census Tract 4005, Alameda County, California        3517

# %% [markdown]
# By the way, Pandas has a built-in short-cut method called 'head' that shows the first 5 rows of a dataframe.  Very handy when the dataframe is large to just look at a few rows.

# %%
df.head(10)
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
# 5         1  Total population  1400000US06001400600  6001400600
# 6         1  Total population  1400000US06001400700  6001400700
# 7         1  Total population  1400000US06001400800  6001400800
# 8         1  Total population  1400000US06001400900  6001400900
# 9         1  Total population  1400000US06001401000  6001401000
#
#                                       geodisplay  Population
# 0  Census Tract 4001, Alameda County, California        2937
# 1  Census Tract 4002, Alameda County, California        1974
# 2  Census Tract 4003, Alameda County, California        4865
# 3  Census Tract 4004, Alameda County, California        3703
# 4  Census Tract 4005, Alameda County, California        3517
# 5  Census Tract 4006, Alameda County, California        1571
# 6  Census Tract 4007, Alameda County, California        4206
# 7  Census Tract 4008, Alameda County, California        3594
# 8  Census Tract 4009, Alameda County, California        2302
# 9  Census Tract 4010, Alameda County, California        5678

# %% [markdown]
# A second way to index is using loc, which uses the labels of the index. Note that this approach includes the second value in the index range, whereas iloc does not.

# %%
df.loc[:5]
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
# 5         1  Total population  1400000US06001400600  6001400600
#
#                                       geodisplay  Population
# 0  Census Tract 4001, Alameda County, California        2937
# 1  Census Tract 4002, Alameda County, California        1974
# 2  Census Tract 4003, Alameda County, California        4865
# 3  Census Tract 4004, Alameda County, California        3703
# 4  Census Tract 4005, Alameda County, California        3517
# 5  Census Tract 4006, Alameda County, California        1571

# %% [markdown]
# Note that indexing can work for both rows and colums

# %%
df.loc[:5, : 'GEOID']
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
# 5         1  Total population  1400000US06001400600  6001400600

# %%
df.iloc[:5, :4]
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500

# %% [markdown]
# We can select rows based on their value as well.  Notice that we nest df[df[condition]] to get this result.

# %%
df[df['Population'] < 200]
# Out:
#       POPGROUP             label             GEOIDLONG       GEOID  \
# 688          1  Total population  1400000US06017031900  6017031900
# 2729         1  Total population  1400000US06037532400  6037532400
# 3051         1  Total population  1400000US06037574700  6037574700
# 3473         1  Total population  1400000US06037930101  6037930101
# 3477         1  Total population  1400000US06037980004  6037980004
# 3478         1  Total population  1400000US06037980008  6037980008
# 3479         1  Total population  1400000US06037980010  6037980010
# 3482         1  Total population  1400000US06037980019  6037980019
# 3483         1  Total population  1400000US06037980024  6037980024
# 4906         1  Total population  1400000US06065940100  6065940100
# 5719         1  Total population  1400000US06073005500  6073005500
# 5726         1  Total population  1400000US06073006200  6073006200
# 6433         1  Total population  1400000US06075980300  6075980300
#
#                                              geodisplay  Population
# 688      Census Tract 319, El Dorado County, California         133
# 2729  Census Tract 5324, Los Angeles County, California         112
# 3051  Census Tract 5747, Los Angeles County, California         117
# 3473  Census Tract 9301.01, Los Angeles County, Cali...         119
# 3477  Census Tract 9800.04, Los Angeles County, Cali...         169
# 3478  Census Tract 9800.08, Los Angeles County, Cali...         145
# 3479  Census Tract 9800.10, Los Angeles County, Cali...         164
# 3482  Census Tract 9800.19, Los Angeles County, Cali...         173
# 3483  Census Tract 9800.24, Los Angeles County, Cali...         186
# 4906    Census Tract 9401, Riverside County, California         166
# 5719      Census Tract 55, San Diego County, California         198
# 5726      Census Tract 62, San Diego County, California         144
# 6433  Census Tract 9803, San Francisco County, Calif...         171

# %% [markdown]
# Below we find and print records that are in El Dorado County, using the str attribute and 'contains' to search for the county name in geodisplay.

# %%
df[df['geodisplay'].str.contains('El Dorado County')]
# Out:
#      POPGROUP             label             GEOIDLONG       GEOID  \
# 648         1  Total population  1400000US06017030200  6017030200
# 649         1  Total population  1400000US06017030301  6017030301
# 650         1  Total population  1400000US06017030302  6017030302
# 651         1  Total population  1400000US06017030401  6017030401
# 652         1  Total population  1400000US06017030402  6017030402
# 653         1  Total population  1400000US06017030502  6017030502
# 654         1  Total population  1400000US06017030504  6017030504
# 655         1  Total population  1400000US06017030505  6017030505
# 656         1  Total population  1400000US06017030601  6017030601
# 657         1  Total population  1400000US06017030602  6017030602
# 658         1  Total population  1400000US06017030603  6017030603
# 659         1  Total population  1400000US06017030701  6017030701
# 660         1  Total population  1400000US06017030704  6017030704
# 661         1  Total population  1400000US06017030706  6017030706
# 662         1  Total population  1400000US06017030709  6017030709
# 663         1  Total population  1400000US06017030710  6017030710
# 664         1  Total population  1400000US06017030801  6017030801
# 665         1  Total population  1400000US06017030803  6017030803
# 666         1  Total population  1400000US06017030804  6017030804
# 667         1  Total population  1400000US06017030807  6017030807
# 668         1  Total population  1400000US06017030808  6017030808
# 669         1  Total population  1400000US06017030809  6017030809
# 670         1  Total population  1400000US06017030810  6017030810
# 671         1  Total population  1400000US06017030901  6017030901
# 672         1  Total population  1400000US06017030902  6017030902
# 673         1  Total population  1400000US06017031000  6017031000
# 674         1  Total population  1400000US06017031100  6017031100
# 675         1  Total population  1400000US06017031200  6017031200
# 676         1  Total population  1400000US06017031301  6017031301
# 677         1  Total population  1400000US06017031302  6017031302
# 678         1  Total population  1400000US06017031402  6017031402
# 679         1  Total population  1400000US06017031404  6017031404
# 680         1  Total population  1400000US06017031405  6017031405
# 681         1  Total population  1400000US06017031406  6017031406
# 682         1  Total population  1400000US06017031502  6017031502
# 683         1  Total population  1400000US06017031503  6017031503
# 684         1  Total population  1400000US06017031504  6017031504
# 685         1  Total population  1400000US06017031600  6017031600
# 686         1  Total population  1400000US06017031700  6017031700
# 687         1  Total population  1400000US06017031800  6017031800
# 688         1  Total population  1400000US06017031900  6017031900
# 689         1  Total population  1400000US06017032000  6017032000
#
#                                             geodisplay  Population
# 648     Census Tract 302, El Dorado County, California        4773
# 649  Census Tract 303.01, El Dorado County, California        2469
# 650  Census Tract 303.02, El Dorado County, California        2867
# 651  Census Tract 304.01, El Dorado County, California        3498
# 652  Census Tract 304.02, El Dorado County, California        3723
# 653  Census Tract 305.02, El Dorado County, California        2641
# 654  Census Tract 305.04, El Dorado County, California        2912
# 655  Census Tract 305.05, El Dorado County, California        2704
# 656  Census Tract 306.01, El Dorado County, California        5044
# 657  Census Tract 306.02, El Dorado County, California        6781
# 658  Census Tract 306.03, El Dorado County, California        3566
# 659  Census Tract 307.01, El Dorado County, California        6205
# 660  Census Tract 307.04, El Dorado County, California        5961
# 661  Census Tract 307.06, El Dorado County, California        6020
# 662  Census Tract 307.09, El Dorado County, California        4806
# 663  Census Tract 307.10, El Dorado County, California        4989
# 664  Census Tract 308.01, El Dorado County, California        4011
# 665  Census Tract 308.03, El Dorado County, California        7241
# 666  Census Tract 308.04, El Dorado County, California        6377
# 667  Census Tract 308.07, El Dorado County, California        3986
# 668  Census Tract 308.08, El Dorado County, California        6897
# 669  Census Tract 308.09, El Dorado County, California        2447
# 670  Census Tract 308.10, El Dorado County, California        3437
# 671  Census Tract 309.01, El Dorado County, California        3020
# 672  Census Tract 309.02, El Dorado County, California        4687
# 673     Census Tract 310, El Dorado County, California        6061
# 674     Census Tract 311, El Dorado County, California        5462
# 675     Census Tract 312, El Dorado County, California        5193
# 676  Census Tract 313.01, El Dorado County, California        3408
# 677  Census Tract 313.02, El Dorado County, California        4701
# 678  Census Tract 314.02, El Dorado County, California        5896
# 679  Census Tract 314.04, El Dorado County, California        2407
# 680  Census Tract 314.05, El Dorado County, California        2426
# 681  Census Tract 314.06, El Dorado County, California        5544
# 682  Census Tract 315.02, El Dorado County, California        6031
# 683  Census Tract 315.03, El Dorado County, California        2810
# 684  Census Tract 315.04, El Dorado County, California        5337
# 685     Census Tract 316, El Dorado County, California        4126
# 686     Census Tract 317, El Dorado County, California        2648
# 687     Census Tract 318, El Dorado County, California        6798
# 688     Census Tract 319, El Dorado County, California         133
# 689     Census Tract 320, El Dorado County, California        1015

# %%
df[df['GEOID']==6017031900]
# Out:
#      POPGROUP             label             GEOIDLONG       GEOID  \
# 688         1  Total population  1400000US06017031900  6017031900
#
#                                          geodisplay  Population
# 688  Census Tract 319, El Dorado County, California         133

# %% [markdown]
# Here we show how to set a value of a cell in the table, identifying a specific row by index label, and setting its population, in this case to a None value, which Pandas interprets as a NaN (missing value).

# %%
df.loc[688,'Population'] = None

# %% [markdown]
# We can filter for values that are Null

# %%
df[df['Population'].isnull()]
# Out:
#      POPGROUP             label             GEOIDLONG       GEOID  \
# 688         1  Total population  1400000US06017031900  6017031900
#
#                                          geodisplay  Population
# 688  Census Tract 319, El Dorado County, California         NaN

# %% [markdown]
# Or more commonly, filter out the null values.

# %%
df[df['Population'].notnull()]
# Out:
#       POPGROUP             label             GEOIDLONG       GEOID  \
# 0            1  Total population  1400000US06001400100  6001400100
# 1            1  Total population  1400000US06001400200  6001400200
# 2            1  Total population  1400000US06001400300  6001400300
# 3            1  Total population  1400000US06001400400  6001400400
# 4            1  Total population  1400000US06001400500  6001400500
# 5            1  Total population  1400000US06001400600  6001400600
# 6            1  Total population  1400000US06001400700  6001400700
# 7            1  Total population  1400000US06001400800  6001400800
# 8            1  Total population  1400000US06001400900  6001400900
# 9            1  Total population  1400000US06001401000  6001401000
# 10           1  Total population  1400000US06001401100  6001401100
# 11           1  Total population  1400000US06001401200  6001401200
# 12           1  Total population  1400000US06001401300  6001401300
# 13           1  Total population  1400000US06001401400  6001401400
# 14           1  Total population  1400000US06001401500  6001401500
# 15           1  Total population  1400000US06001401600  6001401600
# 16           1  Total population  1400000US06001401700  6001401700
# 17           1  Total population  1400000US06001401800  6001401800
# 18           1  Total population  1400000US06001402200  6001402200
# 19           1  Total population  1400000US06001402400  6001402400
# 20           1  Total population  1400000US06001402500  6001402500
# 21           1  Total population  1400000US06001402600  6001402600
# 22           1  Total population  1400000US06001402700  6001402700
# 23           1  Total population  1400000US06001402800  6001402800
# 24           1  Total population  1400000US06001402900  6001402900
# 25           1  Total population  1400000US06001403000  6001403000
# 26           1  Total population  1400000US06001403100  6001403100
# 27           1  Total population  1400000US06001403300  6001403300
# 28           1  Total population  1400000US06001403400  6001403400
# 29           1  Total population  1400000US06001403501  6001403501
# ...        ...               ...                   ...         ...
# 7970         1  Total population  1400000US06113010704  6113010704
# 7971         1  Total population  1400000US06113010800  6113010800
# 7972         1  Total population  1400000US06113010901  6113010901
# 7973         1  Total population  1400000US06113010902  6113010902
# 7974         1  Total population  1400000US06113011001  6113011001
# 7975         1  Total population  1400000US06113011002  6113011002
# 7976         1  Total population  1400000US06113011101  6113011101
# 7977         1  Total population  1400000US06113011102  6113011102
# 7978         1  Total population  1400000US06113011103  6113011103
# 7979         1  Total population  1400000US06113011203  6113011203
# 7980         1  Total population  1400000US06113011204  6113011204
# 7981         1  Total population  1400000US06113011205  6113011205
# 7982         1  Total population  1400000US06113011206  6113011206
# 7983         1  Total population  1400000US06113011300  6113011300
# 7984         1  Total population  1400000US06113011400  6113011400
# 7985         1  Total population  1400000US06113011500  6113011500
# 7986         1  Total population  1400000US06115040100  6115040100
# 7987         1  Total population  1400000US06115040200  6115040200
# 7988         1  Total population  1400000US06115040301  6115040301
# 7989         1  Total population  1400000US06115040302  6115040302
# 7990         1  Total population  1400000US06115040303  6115040303
# 7991         1  Total population  1400000US06115040400  6115040400
# 7992         1  Total population  1400000US06115040500  6115040500
# 7993         1  Total population  1400000US06115040600  6115040600
# 7994         1  Total population  1400000US06115040700  6115040700
# 7995         1  Total population  1400000US06115040800  6115040800
# 7996         1  Total population  1400000US06115040901  6115040901
# 7997         1  Total population  1400000US06115040902  6115040902
# 7998         1  Total population  1400000US06115041000  6115041000
# 7999         1  Total population  1400000US06115041100  6115041100
#
#                                             geodisplay  Population
# 0        Census Tract 4001, Alameda County, California      2937.0
# 1        Census Tract 4002, Alameda County, California      1974.0
# 2        Census Tract 4003, Alameda County, California      4865.0
# 3        Census Tract 4004, Alameda County, California      3703.0
# 4        Census Tract 4005, Alameda County, California      3517.0
# 5        Census Tract 4006, Alameda County, California      1571.0
# 6        Census Tract 4007, Alameda County, California      4206.0
# 7        Census Tract 4008, Alameda County, California      3594.0
# 8        Census Tract 4009, Alameda County, California      2302.0
# 9        Census Tract 4010, Alameda County, California      5678.0
# 10       Census Tract 4011, Alameda County, California      4156.0
# 11       Census Tract 4012, Alameda County, California      2416.0
# %% [markdown]
# The more common use case for this approach would be to replace special values like -9999 with Nan, or vice versa.

# %% [markdown]
# ### String Manipulation in DataFrames
#
# We saw last time how to use the str attribute to do a bit of string manipulation. Below let's create a new column, called 'state', populated by getting the last element in the geodisplay field.

# %%
df['state'] = df['geodisplay'].str.split(',').str[2]
df[:5]
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
#
#                                       geodisplay  Population        state
# 0  Census Tract 4001, Alameda County, California      2937.0   California
# 1  Census Tract 4002, Alameda County, California      1974.0   California
# 2  Census Tract 4003, Alameda County, California      4865.0   California
# 3  Census Tract 4004, Alameda County, California      3703.0   California
# 4  Census Tract 4005, Alameda County, California      3517.0   California

# %% [markdown]
# We use the same approach to add a 'county' column to our dataframe, pulling the values from the geodisplay column.

# %%
df['county'] = df['geodisplay'].str.split(',').str[1].str.replace(' County', '')
df[:5]
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
#
#                                       geodisplay  Population        state  \
# 0  Census Tract 4001, Alameda County, California      2937.0   California
# 1  Census Tract 4002, Alameda County, California      1974.0   California
# 2  Census Tract 4003, Alameda County, California      4865.0   California
# 3  Census Tract 4004, Alameda County, California      3703.0   California
# 4  Census Tract 4005, Alameda County, California      3517.0   California
#
#      county
# 0   Alameda
# 1   Alameda
# 2   Alameda
# 3   Alameda
# 4   Alameda

# %% [markdown]
# Here is a different way to get the County values extrated.

# %%
df['county'] = df['geodisplay'].str.split(',').str[1].str.split(' ').str[1:-1].str.join(' ')
df
# Out:
#       POPGROUP             label             GEOIDLONG       GEOID  \
# 0            1  Total population  1400000US06001400100  6001400100
# 1            1  Total population  1400000US06001400200  6001400200
# 2            1  Total population  1400000US06001400300  6001400300
# 3            1  Total population  1400000US06001400400  6001400400
# 4            1  Total population  1400000US06001400500  6001400500
# 5            1  Total population  1400000US06001400600  6001400600
# 6            1  Total population  1400000US06001400700  6001400700
# 7            1  Total population  1400000US06001400800  6001400800
# 8            1  Total population  1400000US06001400900  6001400900
# 9            1  Total population  1400000US06001401000  6001401000
# 10           1  Total population  1400000US06001401100  6001401100
# 11           1  Total population  1400000US06001401200  6001401200
# 12           1  Total population  1400000US06001401300  6001401300
# 13           1  Total population  1400000US06001401400  6001401400
# 14           1  Total population  1400000US06001401500  6001401500
# 15           1  Total population  1400000US06001401600  6001401600
# 16           1  Total population  1400000US06001401700  6001401700
# 17           1  Total population  1400000US06001401800  6001401800
# 18           1  Total population  1400000US06001402200  6001402200
# 19           1  Total population  1400000US06001402400  6001402400
# 20           1  Total population  1400000US06001402500  6001402500
# 21           1  Total population  1400000US06001402600  6001402600
# 22           1  Total population  1400000US06001402700  6001402700
# 23           1  Total population  1400000US06001402800  6001402800
# 24           1  Total population  1400000US06001402900  6001402900
# 25           1  Total population  1400000US06001403000  6001403000
# 26           1  Total population  1400000US06001403100  6001403100
# 27           1  Total population  1400000US06001403300  6001403300
# 28           1  Total population  1400000US06001403400  6001403400
# 29           1  Total population  1400000US06001403501  6001403501
# ...        ...               ...                   ...         ...
# 7970         1  Total population  1400000US06113010704  6113010704
# 7971         1  Total population  1400000US06113010800  6113010800
# 7972         1  Total population  1400000US06113010901  6113010901
# 7973         1  Total population  1400000US06113010902  6113010902
# 7974         1  Total population  1400000US06113011001  6113011001
# 7975         1  Total population  1400000US06113011002  6113011002
# 7976         1  Total population  1400000US06113011101  6113011101
# 7977         1  Total population  1400000US06113011102  6113011102
# 7978         1  Total population  1400000US06113011103  6113011103
# 7979         1  Total population  1400000US06113011203  6113011203
# 7980         1  Total population  1400000US06113011204  6113011204
# 7981         1  Total population  1400000US06113011205  6113011205
# 7982         1  Total population  1400000US06113011206  6113011206
# 7983         1  Total population  1400000US06113011300  6113011300
# 7984         1  Total population  1400000US06113011400  6113011400
# 7985         1  Total population  1400000US06113011500  6113011500
# 7986         1  Total population  1400000US06115040100  6115040100
# 7987         1  Total population  1400000US06115040200  6115040200
# 7988         1  Total population  1400000US06115040301  6115040301
# 7989         1  Total population  1400000US06115040302  6115040302
# 7990         1  Total population  1400000US06115040303  6115040303
# 7991         1  Total population  1400000US06115040400  6115040400
# 7992         1  Total population  1400000US06115040500  6115040500
# 7993         1  Total population  1400000US06115040600  6115040600
# 7994         1  Total population  1400000US06115040700  6115040700
# 7995         1  Total population  1400000US06115040800  6115040800
# 7996         1  Total population  1400000US06115040901  6115040901
# 7997         1  Total population  1400000US06115040902  6115040902
# 7998         1  Total population  1400000US06115041000  6115041000
# 7999         1  Total population  1400000US06115041100  6115041100
#
#                                             geodisplay  Population  \
# 0        Census Tract 4001, Alameda County, California      2937.0
# 1        Census Tract 4002, Alameda County, California      1974.0
# 2        Census Tract 4003, Alameda County, California      4865.0
# 3        Census Tract 4004, Alameda County, California      3703.0
# 4        Census Tract 4005, Alameda County, California      3517.0
# 5        Census Tract 4006, Alameda County, California      1571.0
# 6        Census Tract 4007, Alameda County, California      4206.0
# 7        Census Tract 4008, Alameda County, California      3594.0
# 8        Census Tract 4009, Alameda County, California      2302.0
# 9        Census Tract 4010, Alameda County, California      5678.0
# 10       Census Tract 4011, Alameda County, California      4156.0
# 11       Census Tract 4012, Alameda County, California      2416.0
# 12       Census Tract 4013, Alameda County, California      3528.0
# 13       Census Tract 4014, Alameda County, California      4314.0
# 14       Census Tract 4015, Alameda County, California      2630.0
# 15       Census Tract 4016, Alameda County, California      2163.0
# 16       Census Tract 4017, Alameda County, California      2667.0
# 17       Census Tract 4018, Alameda County, California      1703.0
# 18       Census Tract 4022, Alameda County, California      2385.0
# 7973   California     Yolo
# 7974   California     Yolo
# 7975   California     Yolo
# 7976   California     Yolo
# 7977   California     Yolo
# 7978   California     Yolo
# 7979   California     Yolo
# 7980   California     Yolo
# 7981   California     Yolo
# 7982   California     Yolo
# 7983   California     Yolo
# 7984   California     Yolo
# 7985   California     Yolo
# 7986   California     Yuba
# 7987   California     Yuba
# 7988   California     Yuba
# 7989   California     Yuba
# 7990   California     Yuba
# 7991   California     Yuba
# 7992   California     Yuba
# 7993   California     Yuba
# 7994   California     Yuba
# 7995   California     Yuba
# 7996   California     Yuba
# 7997   California     Yuba
# 7998   California     Yuba
# 7999   California     Yuba
#
# [8000 rows x 8 columns]

# %%
df['FIPSSTATE'] = df['GEOIDLONG'].str[9:11]
df.head()
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
#
#                                       geodisplay  Population        state  \
# 0  Census Tract 4001, Alameda County, California      2937.0   California
# 1  Census Tract 4002, Alameda County, California      1974.0   California
# 2  Census Tract 4003, Alameda County, California      4865.0   California
# 3  Census Tract 4004, Alameda County, California      3703.0   California
# 4  Census Tract 4005, Alameda County, California      3517.0   California
#
#      county FIPSSTATE
# 0   Alameda        06
# 1   Alameda        06
# 2   Alameda        06
# 3   Alameda        06
# 4   Alameda        06

# %% [markdown]
# Let's test to make sure our approach preserves two word County names..

# %%
df[df['geodisplay'].str.contains('El Dorado County')]
# Out:
#      POPGROUP             label             GEOIDLONG       GEOID  \
# 648         1  Total population  1400000US06017030200  6017030200
# 649         1  Total population  1400000US06017030301  6017030301
# 650         1  Total population  1400000US06017030302  6017030302
# 651         1  Total population  1400000US06017030401  6017030401
# 652         1  Total population  1400000US06017030402  6017030402
# 653         1  Total population  1400000US06017030502  6017030502
# 654         1  Total population  1400000US06017030504  6017030504
# 655         1  Total population  1400000US06017030505  6017030505
# 656         1  Total population  1400000US06017030601  6017030601
# 657         1  Total population  1400000US06017030602  6017030602
# 658         1  Total population  1400000US06017030603  6017030603
# 659         1  Total population  1400000US06017030701  6017030701
# 660         1  Total population  1400000US06017030704  6017030704
# 661         1  Total population  1400000US06017030706  6017030706
# 662         1  Total population  1400000US06017030709  6017030709
# 663         1  Total population  1400000US06017030710  6017030710
# 664         1  Total population  1400000US06017030801  6017030801
# 665         1  Total population  1400000US06017030803  6017030803
# 666         1  Total population  1400000US06017030804  6017030804
# 667         1  Total population  1400000US06017030807  6017030807
# 668         1  Total population  1400000US06017030808  6017030808
# 669         1  Total population  1400000US06017030809  6017030809
# 670         1  Total population  1400000US06017030810  6017030810
# 671         1  Total population  1400000US06017030901  6017030901
# 672         1  Total population  1400000US06017030902  6017030902
# 673         1  Total population  1400000US06017031000  6017031000
# 674         1  Total population  1400000US06017031100  6017031100
# 675         1  Total population  1400000US06017031200  6017031200
#
#            state      county FIPSSTATE
# 648   California   El Dorado        06
# 649   California   El Dorado        06
# 650   California   El Dorado        06
# 651   California   El Dorado        06
# 652   California   El Dorado        06
# 653   California   El Dorado        06
# 654   California   El Dorado        06
# 655   California   El Dorado        06
# 656   California   El Dorado        06
# 657   California   El Dorado        06
# 658   California   El Dorado        06
# 659   California   El Dorado        06
# 660   California   El Dorado        06
# 661   California   El Dorado        06
# 662   California   El Dorado        06
# 663   California   El Dorado        06
# 664   California   El Dorado        06
# 665   California   El Dorado        06
# 666   California   El Dorado        06
# 667   California   El Dorado        06
# 668   California   El Dorado        06
# 669   California   El Dorado        06
# 670   California   El Dorado        06
# 671   California   El Dorado        06
# 672   California   El Dorado        06
# 673   California   El Dorado        06
# 674   California   El Dorado        06
# 675   California   El Dorado        06
# 676   California   El Dorado        06
# 677   California   El Dorado        06
# 678   California   El Dorado        06
# 679   California   El Dorado        06
# 680   California   El Dorado        06
# 681   California   El Dorado        06
# 682   California   El Dorado        06
# 683   California   El Dorado        06
# 684   California   El Dorado        06
# 685   California   El Dorado        06
# 686   California   El Dorado        06
# 687   California   El Dorado        06
# 688   California   El Dorado        06
# 689   California   El Dorado        06

# %% [markdown]
# Let's see what the full list of unique county names is...

# %%
df['county'].unique()
# Out:
# array([' Alameda', ' Alpine', ' Amador', ' Butte', ' Calaveras',
#        ' Colusa', ' Contra Costa', ' Del Norte', ' El Dorado', ' Fresno',
#        ' Glenn', ' Humboldt', ' Imperial', ' Inyo', ' Kern', ' Kings',
#        ' Lake', ' Lassen', ' Los Angeles', ' Madera', ' Marin',
#        ' Mariposa', ' Mendocino', ' Merced', ' Modoc', ' Mono',
#        ' Monterey', ' Napa', ' Nevada', ' Orange', ' Placer', ' Plumas',
#        ' Riverside', ' Sacramento', ' San Benito', ' San Bernardino',
#        ' San Diego', ' San Francisco', ' San Joaquin', ' San Luis Obispo',
#        ' San Mateo', ' Santa Barbara', ' Santa Clara', ' Santa Cruz',
#        ' Shasta', ' Sierra', ' Siskiyou', ' Solano', ' Sonoma',
#        ' Stanislaus', ' Sutter', ' Tehama', ' Trinity', ' Tulare',
#        ' Tuolumne', ' Ventura', ' Yolo', ' Yuba'], dtype=object)

# %% [markdown]
# Check-in time: How would you count how many census tracts are in each county? http://bitly.com/cp255

# %% [markdown]
# Now let's create a census tract column.

# %%
df['Tract'] = df['geodisplay'].str.split(',').str[0].str.split().str[2]
df
# Out:
#       POPGROUP             label             GEOIDLONG       GEOID  \
# 0            1  Total population  1400000US06001400100  6001400100
# 1            1  Total population  1400000US06001400200  6001400200
# 2            1  Total population  1400000US06001400300  6001400300
# 3            1  Total population  1400000US06001400400  6001400400
# 4            1  Total population  1400000US06001400500  6001400500
# 5            1  Total population  1400000US06001400600  6001400600
# 6            1  Total population  1400000US06001400700  6001400700
# 7            1  Total population  1400000US06001400800  6001400800
# 8            1  Total population  1400000US06001400900  6001400900
# 9            1  Total population  1400000US06001401000  6001401000
# 10           1  Total population  1400000US06001401100  6001401100
# 11           1  Total population  1400000US06001401200  6001401200
# 12           1  Total population  1400000US06001401300  6001401300
# 13           1  Total population  1400000US06001401400  6001401400
# 14           1  Total population  1400000US06001401500  6001401500
# 15           1  Total population  1400000US06001401600  6001401600
# 16           1  Total population  1400000US06001401700  6001401700
# 17           1  Total population  1400000US06001401800  6001401800
# 18           1  Total population  1400000US06001402200  6001402200
# 19           1  Total population  1400000US06001402400  6001402400
# 20           1  Total population  1400000US06001402500  6001402500
# 21           1  Total population  1400000US06001402600  6001402600
# 22           1  Total population  1400000US06001402700  6001402700
# 23           1  Total population  1400000US06001402800  6001402800
# 24           1  Total population  1400000US06001402900  6001402900
# 25           1  Total population  1400000US06001403000  6001403000
# 26           1  Total population  1400000US06001403100  6001403100
# 27           1  Total population  1400000US06001403300  6001403300
# 28           1  Total population  1400000US06001403400  6001403400
# 29           1  Total population  1400000US06001403501  6001403501
# ...        ...               ...                   ...         ...
# 7970         1  Total population  1400000US06113010704  6113010704
# 7971         1  Total population  1400000US06113010800  6113010800
# 7972         1  Total population  1400000US06113010901  6113010901
# 7973         1  Total population  1400000US06113010902  6113010902
# 7974         1  Total population  1400000US06113011001  6113011001
# 7975         1  Total population  1400000US06113011002  6113011002
# 7976         1  Total population  1400000US06113011101  6113011101
# 7977         1  Total population  1400000US06113011102  6113011102
# 7978         1  Total population  1400000US06113011103  6113011103
# 7979         1  Total population  1400000US06113011203  6113011203
# 7980         1  Total population  1400000US06113011204  6113011204
# 7981         1  Total population  1400000US06113011205  6113011205
# 7982         1  Total population  1400000US06113011206  6113011206
# 7983         1  Total population  1400000US06113011300  6113011300
# 7984         1  Total population  1400000US06113011400  6113011400
# 7985         1  Total population  1400000US06113011500  6113011500
# 7986         1  Total population  1400000US06115040100  6115040100
# 7987         1  Total population  1400000US06115040200  6115040200
# 7988         1  Total population  1400000US06115040301  6115040301
# 7989         1  Total population  1400000US06115040302  6115040302
# 7990         1  Total population  1400000US06115040303  6115040303
# 7991         1  Total population  1400000US06115040400  6115040400
# 7992         1  Total population  1400000US06115040500  6115040500
# 7993         1  Total population  1400000US06115040600  6115040600
# 7994         1  Total population  1400000US06115040700  6115040700
# 7995         1  Total population  1400000US06115040800  6115040800
# 7996         1  Total population  1400000US06115040901  6115040901
# 7997         1  Total population  1400000US06115040902  6115040902
# 7998         1  Total population  1400000US06115041000  6115041000
# 7999         1  Total population  1400000US06115041100  6115041100
#
#                                             geodisplay  Population  \
# 0        Census Tract 4001, Alameda County, California      2937.0
# 1        Census Tract 4002, Alameda County, California      1974.0
# 2        Census Tract 4003, Alameda County, California      4865.0
# 3        Census Tract 4004, Alameda County, California      3703.0
# 4        Census Tract 4005, Alameda County, California      3517.0
# 5        Census Tract 4006, Alameda County, California      1571.0
# 6        Census Tract 4007, Alameda County, California      4206.0
# 7        Census Tract 4008, Alameda County, California      3594.0
# 8        Census Tract 4009, Alameda County, California      2302.0
# 9        Census Tract 4010, Alameda County, California      5678.0
# 9      California   Alameda        06     4010
# 10     California   Alameda        06     4011
# 11     California   Alameda        06     4012
# 12     California   Alameda        06     4013
# 13     California   Alameda        06     4014
# 14     California   Alameda        06     4015
# 15     California   Alameda        06     4016
# 16     California   Alameda        06     4017
# 17     California   Alameda        06     4018
# 18     California   Alameda        06     4022
# 19     California   Alameda        06     4024
# 20     California   Alameda        06     4025
# 21     California   Alameda        06     4026
# 22     California   Alameda        06     4027
# 23     California   Alameda        06     4028
# 24     California   Alameda        06     4029
# 25     California   Alameda        06     4030
# 26     California   Alameda        06     4031
# 27     California   Alameda        06     4033
# 28     California   Alameda        06     4034
# 29     California   Alameda        06  4035.01
# ...           ...       ...       ...      ...
# 7970   California      Yolo        06   107.04
# 7971   California      Yolo        06      108
# 7972   California      Yolo        06   109.01
# 7973   California      Yolo        06   109.02
# 7974   California      Yolo        06   110.01
# 7975   California      Yolo        06   110.02
# 7976   California      Yolo        06   111.01
# 7977   California      Yolo        06   111.02
# 7978   California      Yolo        06   111.03
# 7979   California      Yolo        06   112.03
# 7980   California      Yolo        06   112.04
# 7981   California      Yolo        06   112.05
# 7982   California      Yolo        06   112.06
# 7983   California      Yolo        06      113
# 7984   California      Yolo        06      114
# 7985   California      Yolo        06      115
# 7986   California      Yuba        06      401
# 7987   California      Yuba        06      402
# 7988   California      Yuba        06   403.01
# 7989   California      Yuba        06   403.02
# 7990   California      Yuba        06   403.03
# 7991   California      Yuba        06      404
# 7992   California      Yuba        06      405
# 7993   California      Yuba        06      406
# 7994   California      Yuba        06      407
# 7995   California      Yuba        06      408
# 7996   California      Yuba        06   409.01
# 7997   California      Yuba        06   409.02
# 7998   California      Yuba        06      410
# 7999   California      Yuba        06      411
#
# [8000 rows x 10 columns]

# %% [markdown]
# Could you extract Tract from the GEOIDLONG column instead?

# %%
df['Tract'] = df['GEOIDLONG'].str[-6:-2] + '.' + df['GEOIDLONG'].str[-2:]
df.head()
# Out:
#    POPGROUP             label             GEOIDLONG       GEOID  \
# 0         1  Total population  1400000US06001400100  6001400100
# 1         1  Total population  1400000US06001400200  6001400200
# 2         1  Total population  1400000US06001400300  6001400300
# 3         1  Total population  1400000US06001400400  6001400400
# 4         1  Total population  1400000US06001400500  6001400500
#
#                                       geodisplay  Population        state  \
# 0  Census Tract 4001, Alameda County, California      2937.0   California
# 1  Census Tract 4002, Alameda County, California      1974.0   California
# 2  Census Tract 4003, Alameda County, California      4865.0   California
# 3  Census Tract 4004, Alameda County, California      3703.0   California
# 4  Census Tract 4005, Alameda County, California      3517.0   California
#
#     county    Tract
# 0  Alameda  4001.00
# 1  Alameda  4002.00
# 2  Alameda  4003.00
# 3  Alameda  4004.00
# 4  Alameda  4005.00

# %% [markdown]
# ## Merging / Joining Dataframes
#
# Pandas has a very powerful set of methods to merge dataframes. Let's review some on a simple example)

# %%
favorite_numbers = pd.DataFrame(
    [["Paul", 42],
     ["Paul", 3.14],
     ["Arezoo", 7],
     ["Arezoo", 9],
     ["Sam", 3],
     ["Geoff", np.NaN]], columns = ["Name", "Number"])
email_addr = pd.DataFrame(
    [["Paul", "waddell@berkeley.edu"],
     ["Arezoo", "arezoo.bz@berkeley.edu"],
     ["Sam", "maurer@berkeley.edu"],
     ["Geoff", "gboeing@berkeley.edu"],
     ["Max", "magardner@berkeley.edu"]], columns = ["Name", "Email"])

# %% [markdown]
# The first table contains favorite numbers of some famous people.  (The numbers have been changed to protect their identity.)

# %%
favorite_numbers
# Out:
#      Name  Number
# 0    Paul   42.00
# 1    Paul    3.14
# 2  Arezoo    7.00
# 3  Arezoo    9.00
# 4     Sam    3.00
# 5   Geoff     NaN

# %% [markdown]
# The second table contains the individuals email addresses.

# %%
email_addr
# Out:
#      Name                   Email
# 0    Paul    waddell@berkeley.edu
# 1  Arezoo  arezoo.bz@berkeley.edu
# 2     Sam     maurer@berkeley.edu
# 3   Geoff    gboeing@berkeley.edu
# 4     Max  magardner@berkeley.edu

# %% [markdown]
# ## Many ways to join the data
#
# There are actually many ways you could imagine combining data from both of these tables.  In the following we work through a few example methods.

# %% [markdown]
# ### Merge
#
# Probably the most general and standard way to join tables in pandas is to use the merge function:

# %%
pd.merge(favorite_numbers, email_addr)
# Out:
#      Name  Number                   Email
# 0    Paul   42.00    waddell@berkeley.edu
# 1    Paul    3.14    waddell@berkeley.edu
# 2  Arezoo    7.00  arezoo.bz@berkeley.edu
# 3  Arezoo    9.00  arezoo.bz@berkeley.edu
# 4     Sam    3.00     maurer@berkeley.edu
# 5   Geoff     NaN    gboeing@berkeley.edu

# %% [markdown]
# Notice in the above join that:
# 1. The **`Name`** column is used to define which records match from each table.  Pandas will by default join on any matching column names.
# 1. Only the records that occur in both tables are included in the final table.  This is called an inner join.
# 1. Joey occurs 4 times since the name Joey had two email addresses and two favorite numbers.
#
# Many of the joins you will do in data science will either be inner joins or left joins (see below).
#
# We could be more specific about the join using the following additional arguments.

# %%
pd.merge(favorite_numbers, email_addr, on="Name", how="inner")
# Out:
#      Name  Number                   Email
# 0    Paul   42.00    waddell@berkeley.edu
# 1    Paul    3.14    waddell@berkeley.edu
# 2  Arezoo    7.00  arezoo.bz@berkeley.edu
# 3  Arezoo    9.00  arezoo.bz@berkeley.edu
# 4     Sam    3.00     maurer@berkeley.edu
# 5   Geoff     NaN    gboeing@berkeley.edu

# %% [markdown]
# #### Left Merge
#
# A left join will keep all the entries in the left table even if they have no matching entry in the right table.  For example we didn't have Nhi or Bob's email address and so they appear as missing values rather than being dropped from the join.

# %%
pd.merge(favorite_numbers, email_addr, on="Name",how="right")
# Out:
#      Name  Number                   Email
# 0    Paul   42.00    waddell@berkeley.edu
# 1    Paul    3.14    waddell@berkeley.edu
# 2  Arezoo    7.00  arezoo.bz@berkeley.edu
# 3  Arezoo    9.00  arezoo.bz@berkeley.edu
# 4     Sam    3.00     maurer@berkeley.edu
# 5   Geoff     NaN    gboeing@berkeley.edu
# 6     Max     NaN  magardner@berkeley.edu

# %% [markdown]
# #### Outer Merge
#
# The outer join keeps entries in both tables even if they don't have a match in the other and substitutes NaN for missing values.

# %%
pd.merge(favorite_numbers, email_addr, on="Name", how="outer")
# Out:
#      Name  Number                   Email
# 0    Paul   42.00    waddell@berkeley.edu
# 1    Paul    3.14    waddell@berkeley.edu
# 2  Arezoo    7.00  arezoo.bz@berkeley.edu
# 3  Arezoo    9.00  arezoo.bz@berkeley.edu
# 4     Sam    3.00     maurer@berkeley.edu
# 5   Geoff     NaN    gboeing@berkeley.edu
# 6     Max     NaN  magardner@berkeley.edu

# %% [markdown]
# ### Join
#
# Pandas also provides a join function which joins two tables on their index.  This function also let's you specify what kind of join you would like.

# %%
favorite_numbers.set_index("Name").join(email_addr.set_index("Name"), how="inner")
# Out:
#         Number                   Email
# Name
# Arezoo    7.00  arezoo.bz@berkeley.edu
# Arezoo    9.00  arezoo.bz@berkeley.edu
# Geoff      NaN    gboeing@berkeley.edu
# Paul     42.00    waddell@berkeley.edu
# Paul      3.14    waddell@berkeley.edu
# Sam       3.00     maurer@berkeley.edu

# %% [markdown]
# ### More resources to learn about merges and joins
#
# These are powerful tools and there are some subtleties in using them.  I recommend doing a fair amount of reading and a lot of practicing to get these ideas and the accompanying syntax internalized into your programming toolkit.
#
# Here is another good (and short) tutorial: https://chrisalbon.com/python/pandas_join_merge_dataframe.html
#
# And as always, **ReadTheDocs**: http://pandas.pydata.org/pandas-docs/stable/merging.html#database-style-dataframe-joining-merging

# %% [markdown]
# ## Using Merge on Real Datasets and Using String Operations
#
# Now that we have some concepts and syntax under control, let's try using them on some larger data tables from the Census, and learn how to use string operations to work with these data.
#
# ### County level Census Data for the U.S.
#
# Lets say we want to analyze county level population trends. I downloaded population two estimates tables for U.S. Counties: one contains 2000-2010, and the other has 2010-2016.  Lets load them and do some data exploration and manipulation to get a merged county level population series for the 2000 - 2016 period.
#
# One thing that you will encounter as you get csv files from various locations, is that the character encoding might be unusual, and require setting the encoding on the read statement.  Full documentation on this is available here:
# https://docs.python.org/3/library/codecs.html#standard-encodings
#
# Some of the most common ones are:
#
# Latin1
# iso-8859-1
# utf_8
# utf_16
# utf_32
#
# Let's see what happens when you try loading a csv file with an encoding issue:

# %%
co00 = pd.read_csv('data/co-est00int-tot.csv', encoding='Latin1')
co00.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  \
# 0            4447207          4452173          4467634          4480089
# 1              43751            44021            44889            45909
# 2             140416           141342           144875           147957
# 3              29042            29015            28863            28653
# 4              19856            19913            21028            21199
#
#    POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  \
# 0          4503491          4530729          4569805          4628981
# 1            46800            48366            49676            51328
# 2           151509           156266           162183           168121
# 3            28594            28287            28027            27861
# 4            21399            21721            22042            22099
#
#    POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# 0          4672840          4718206          4757938        4779736
# 1            52405            53277            54135          54571
# 2           172404           175827           179406         182265
# 3            27757            27808            27657          27457
# 4            22438            22705            22941          22915
#
#    POPESTIMATE2010
# 0          4785298
# 1            54632
# 2           183195
# 3            27411
# 4            22867

# %%
co00 = pd.read_csv('data/co-est00int-tot.csv', encoding='Latin1')
co00.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  \
# 0            4447207          4452173          4467634          4480089
# 1              43751            44021            44889            45909
# 2             140416           141342           144875           147957
# 3              29042            29015            28863            28653
# 4              19856            19913            21028            21199
#
#    POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  \
# 0          4503491          4530729          4569805          4628981
# 1            46800            48366            49676            51328
# 2           151509           156266           162183           168121
# 3            28594            28287            28027            27861
# 4            21399            21721            22042            22099
#
#    POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# 0          4672840          4718206          4757938        4779736
# 1            52405            53277            54135          54571
# 2           172404           175827           179406         182265
# 3            27757            27808            27657          27457
# 4            22438            22705            22941          22915
#
#    POPESTIMATE2010
# 0          4785298
# 1            54632
# 2           183195
# 3            27411
# 4            22867

# %%
co16 = pd.read_csv('data/co-est2016-alldata.csv', encoding='latin1')
co16.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780131          4785492     ...
# 1          54571              54571            54742     ...
# 2         182265             182265           183199     ...
# 3          27457              27457            27348     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  RDOMESTICMIG2016  \
# 0          0.335703          0.086842         -0.642255         -0.177829
# 1         -4.607582          2.149969         -2.799695          4.128528
# 2         21.672935         19.038117         17.311339         19.628723
# 3         -7.027927         -4.208488        -16.593442         -9.495549
# 4         -6.556506          0.088865          0.088747          1.504292
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# 0     0.709411     1.062617     1.202226     1.065267     0.411670
# 1     6.163804    -5.295515    -4.571158     2.259290    -2.654256
# 2    15.757654    18.612620    22.757100    20.248574    18.585398
# 3    -1.280316    -7.418561    -7.360829    -4.506434   -16.819716
# 4    -4.956466    -4.318988    -5.980596     0.888652     0.887469
#
#    RNETMIG2016
# 0     0.797351
# 1     4.255281
# 2    20.807611
# 3    -9.686991
# 4     2.300681
#
# [5 rows x 116 columns]

# %%
list(co16.columns)
# Out:
# ['SUMLEV',
#  'REGION',
#  'DIVISION',
#  'STATE',
#  'COUNTY',
#  'STNAME',
#  'CTYNAME',
#  'CENSUS2010POP',
#  'ESTIMATESBASE2010',
#  'POPESTIMATE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015',
#  'POPESTIMATE2016',
#  'NPOPCHG_2010',
#  'NPOPCHG_2011',
#  'NPOPCHG_2012',
#  'NPOPCHG_2013',
#  'NPOPCHG_2014',
#  'NPOPCHG_2015',
#  'NPOPCHG_2016',
#  'BIRTHS2010',
#  'BIRTHS2011',
#  'BIRTHS2012',
#  'BIRTHS2013',
#  'BIRTHS2014',
#  'BIRTHS2015',
#  'BIRTHS2016',
#  'DEATHS2010',
#  'DEATHS2011',
#  'DEATHS2012',
#  'DEATHS2013',
#  'DEATHS2014',
#  'DEATHS2015',
#  'DEATHS2016',
#  'NATURALINC2010',
#  'NATURALINC2011',
#  'NATURALINC2012',
#  'NATURALINC2013',
#  'NATURALINC2014',
#  'NATURALINC2015',
#  'NATURALINC2016',
#  'INTERNATIONALMIG2010',
#  'INTERNATIONALMIG2011',
#  'INTERNATIONALMIG2012',
#  'INTERNATIONALMIG2013',
#  'INTERNATIONALMIG2014',
#  'INTERNATIONALMIG2015',
#  'INTERNATIONALMIG2016',
#  'DOMESTICMIG2010',
#  'DOMESTICMIG2011',
#  'DOMESTICMIG2012',
#  'DOMESTICMIG2013',
#  'DOMESTICMIG2014',
#  'DOMESTICMIG2015',
#  'DOMESTICMIG2016',
#  'NETMIG2010',
#  'NETMIG2011',
#  'NETMIG2012',
#  'NETMIG2013',
#  'NETMIG2014',
#  'NETMIG2015',
#  'NETMIG2016',
#  'RESIDUAL2010',
#  'RESIDUAL2011',
#  'RESIDUAL2012',
#  'RESIDUAL2013',
#  'RESIDUAL2014',
#  'RESIDUAL2015',
#  'RESIDUAL2016',
#  'GQESTIMATESBASE2010',
#  'GQESTIMATES2010',
#  'GQESTIMATES2011',
#  'GQESTIMATES2012',
#  'GQESTIMATES2013',
#  'GQESTIMATES2014',
#  'GQESTIMATES2015',
#  'GQESTIMATES2016',
#  'RBIRTH2011',
#  'RBIRTH2012',
#  'RBIRTH2013',
#  'RBIRTH2014',
#  'RBIRTH2015',
#  'RBIRTH2016',
#  'RDEATH2011',
#  'RDEATH2012',
#  'RDEATH2013',
#  'RDEATH2014',
#  'RDEATH2015',
#  'RDEATH2016',
#  'RNATURALINC2011',
#  'RNATURALINC2012',
#  'RNATURALINC2013',
#  'RNATURALINC2014',
#  'RNATURALINC2015',
#  'RNATURALINC2016',
#  'RINTERNATIONALMIG2011',
#  'RINTERNATIONALMIG2012',
#  'RINTERNATIONALMIG2013',
#  'RINTERNATIONALMIG2014',
#  'RINTERNATIONALMIG2015',
#  'RINTERNATIONALMIG2016',
#  'RDOMESTICMIG2011',
#  'RDOMESTICMIG2012',
#  'RDOMESTICMIG2013',
#  'RDOMESTICMIG2014',
#  'RDOMESTICMIG2015',
#  'RDOMESTICMIG2016',
#  'RNETMIG2011',
#  'RNETMIG2012',
#  'RNETMIG2013',
#  'RNETMIG2014',
#  'RNETMIG2015',
#  'RNETMIG2016']

# %% [markdown]
# **116 columns!?!  We don't want all of those!  How can we keep just the columns we want? The ones containing POPESTIMATE, and the initial geographic columns?**

# %%
co16s = co16.loc[:,:'POPESTIMATE2016']
co16s.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016'],
#       dtype='object')

# %% [markdown]
# Ahhh, that's better...

# %%
co16s.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0        4779736            4780131          4785492          4799918
# 1          54571              54571            54742            55255
# 2         182265             182265           183199           186653
# 3          27457              27457            27348            27326
# 4          22915              22919            22861            22736
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 0          4815960          4829479          4843214          4853875
# 1            55027            54792            54977            55035
# 2           190403           195147           199745           203690
# 3            27132            26938            26763            26270
# 4            22645            22501            22511            22561
#
#    POPESTIMATE2016
# 0          4863300
# 1            55416
# 2           208563
# 3            25965
# 4            22643

# %% [markdown]
# **But wait... what's going on here?  There seem to be at least two SUMLEV values and it looks suspiciously like there are State level summaries of POPESTIMATES embedded in this County-level file.  Let's check how many records there are for each SUMLEV in the file...**

# %%
co16s['SUMLEV'].value_counts()
# Out:
# 50    3142
# 40      51
# Name: SUMLEV, dtype: int64

# %% [markdown]
# Hmm, OK, so we have 51 SUMLEV 40, which seem to be States, plus one... let's pull those into a new dataframe.

# %%
st00 = co00[co00['SUMLEV']==40]
st00.head()
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME     CTYNAME  \
# 0        40       3         6      1       0     Alabama     Alabama
# 68       40       4         9      2       0      Alaska      Alaska
# 98       40       4         8      4       0     Arizona     Arizona
# 114      40       3         7      5       0    Arkansas    Arkansas
# 190      40       4         9      6       0  California  California
#
#      ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  \
# 0              4447207          4452173          4467634          4480089
# 68              626933           627963           633714           642337
# 98             5130247          5160586          5273477          5396255
# 114            2673293          2678588          2691571          2705927
# 190           33871653         33987977         34479458         34871843
#
#      POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  \
# 0            4503491          4530729          4569805          4628981
# 68            648414           659286           666946           675302
# 98           5510364          5652404          5839077          6029141
# 114          2724816          2749686          2781097          2821761
# 190         35253159         35574576         35827943         36021202
#
#      POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# 0            4672840          4718206          4757938        4779736
# 68            680300           687455           698895         710231
# 98           6167681          6280362          6343154        6392017
# 114          2848650          2874554          2896843        2915918
# 190         36250311         36604337         36961229       37253956
#
#      POPESTIMATE2010
# 0            4785298
# 68            713985
# 98           6413737
# 114          2921606
# 190         37349363

# %%
st00.shape
# Out:
# (51, 20)

# %%
st00['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# So what is that 51st entry in the set of States?
#
# Now let's pull the state records out of the 2016 file.

# %%
st16 = co16s[co16s['SUMLEV']==40]
st16.head()
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME     CTYNAME  \
# 0        40       3         6      1       0     Alabama     Alabama
# 68       40       4         9      2       0      Alaska      Alaska
# 98       40       4         8      4       0     Arizona     Arizona
# 114      40       3         7      5       0    Arkansas    Arkansas
# 190      40       4         9      6       0  California  California
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0          4779736            4780131          4785492          4799918
# 68          710231             710249           714031           722713
# 98         6392017            6392301          6408312          6467163
# 114        2915918            2916025          2921995          2939493
# 190       37253956           37254522         37332685         37676861
#
#      POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 0            4815960          4829479          4843214          4853875
# 68            731089           736879           736705           737709
# 98           6549634          6624617          6719993          6817565
# 114          2950685          2958663          2966912          2977853
# 190         38011074         38335203         38680810         38993940
#
#      POPESTIMATE2016
# 0            4863300
# 68            741894
# 98           6931071
# 114          2988248
# 190         39250017

# %% [markdown]
# **Now how can we merge the 2000 and 2016 state dataframes?**

# %%
stjoin = pd.merge(st00,st16, on='STATE')
stjoin.head()
# Out:
#    SUMLEV_x  REGION_x  DIVISION_x  STATE  COUNTY_x    STNAME_x   CTYNAME_x  \
# 0        40         3           6      1         0     Alabama     Alabama
# 1        40         4           9      2         0      Alaska      Alaska
# 2        40         4           8      4         0     Arizona     Arizona
# 3        40         3           7      5         0    Arkansas    Arkansas
# 4        40         4           9      6         0  California  California
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001       ...         \
# 0            4447207          4452173          4467634       ...
# 1             626933           627963           633714       ...
# 2            5130247          5160586          5273477       ...
# 3            2673293          2678588          2691571       ...
# 4           33871653         33987977         34479458       ...
#
#     CTYNAME_y  CENSUS2010POP_y  ESTIMATESBASE2010  POPESTIMATE2010_y  \
# 0     Alabama          4779736            4780131            4785492
# 1      Alaska           710231             710249             714031
# 2     Arizona          6392017            6392301            6408312
# 3    Arkansas          2915918            2916025            2921995
# 4  California         37253956           37254522           37332685
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0          4799918          4815960          4829479          4843214
# 1           722713           731089           736879           736705
# 2          6467163          6549634          6624617          6719993
# 3          2939493          2950685          2958663          2966912
# 4         37676861         38011074         38335203         38680810
#
#    POPESTIMATE2015  POPESTIMATE2016
# 0          4853875          4863300
# 1           737709           741894
# 2          6817565          6931071
# 3          2977853          2988248
# 4         38993940         39250017
#
# [5 rows x 35 columns]

# %% [markdown]
# **Looks like it worked!  But what are all those columns with _x and _y suffixes?**
#
# Seems like a mess to keep all those duplicate columns and have them get renamed like this... what to do...?
#
# Maybe we could find the columns that are different in the second dataframe and just add those to the first dataframe?

# %%
cols_to_use = list(st16.columns.difference(st00.columns))
cols_to_use
# Out:
# ['ESTIMATESBASE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015',
#  'POPESTIMATE2016']

# %% [markdown]
# Would it work if we tried to join these two using this as the list of columns from ST16?  What would be the join column? Seems like that would be pretty handy to have...

# %%
cols_to_use.append('STATE')
cols_to_use
# Out:
# ['ESTIMATESBASE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015',
#  'POPESTIMATE2016',
#  'STATE']

# %% [markdown]
# Now we can do a cleaner merge using STATE:

# %%
stjoin2 = pd.merge(st00, st16[cols_to_use], on='STATE')
stjoin2.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME     CTYNAME  \
# 0      40       3         6      1       0     Alabama     Alabama
# 1      40       4         9      2       0      Alaska      Alaska
# 2      40       4         8      4       0     Arizona     Arizona
# 3      40       3         7      5       0    Arkansas    Arkansas
# 4      40       4         9      6       0  California  California
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001       ...         \
# 0            4447207          4452173          4467634       ...
# 1             626933           627963           633714       ...
# 2            5130247          5160586          5273477       ...
# 3            2673293          2678588          2691571       ...
# 4           33871653         33987977         34479458       ...
#
#    POPESTIMATE2009  CENSUS2010POP  POPESTIMATE2010  ESTIMATESBASE2010  \
# 0          4757938        4779736          4785298            4780131
# 1           698895         710231           713985             710249
# 2          6343154        6392017          6413737            6392301
# 3          2896843        2915918          2921606            2916025
# 4         36961229       37253956         37349363           37254522
#
#    POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# 0          4799918          4815960          4829479          4843214
# 1           722713           731089           736879           736705
# 2          6467163          6549634          6624617          6719993
# 3          2939493          2950685          2958663          2966912
# 4         37676861         38011074         38335203         38680810
#
#    POPESTIMATE2015  POPESTIMATE2016
# 0          4853875          4863300
# 1           737709           741894
# 2          6817565          6931071
# 3          2977853          2988248
# 4         38993940         39250017
#
# [5 rows x 27 columns]

# %% [markdown]
# Looking pretty good.  But there are still a lot of columns we really don't want.  Let's drop those, and set the index to STNAME.

# %%
stjoin3 = stjoin2.drop(['SUMLEV','REGION','DIVISION','COUNTY','ESTIMATESBASE2000','ESTIMATESBASE2010','CENSUS2010POP','CTYNAME'], axis=1)
stjoin3.set_index('STNAME')
# Out:
#                       STATE  POPESTIMATE2000  POPESTIMATE2001  \
# STNAME
# Alabama                   1          4452173          4467634
# Alaska                    2           627963           633714
# Arizona                   4          5160586          5273477
# Arkansas                  5          2678588          2691571
# California                6         33987977         34479458
# Colorado                  8          4326921          4425687
# Connecticut               9          3411777          3432835
# Delaware                 10           786373           795699
# District of Columbia     11           572046           574504
# Florida                  12         16047515         16356966
# Georgia                  13          8227303          8377038
# Hawaii                   15          1213519          1225948
# Idaho                    16          1299430          1319962
# Illinois                 17         12434161         12488445
# Indiana                  18          6091866          6127760
# Iowa                     19          2929067          2931997
# Kansas                   20          2693681          2702162
# Kentucky                 21          4049021          4068132
# Louisiana                22          4471885          4477875
# Maine                    23          1277072          1285692
# Maryland                 24          5311034          5374691
# Massachusetts            25          6361104          6397634
# Michigan                 26          9952450          9991120
# Minnesota                27          4933692          4982796
# Mississippi              28          2848353          2852994
# Missouri                 29          5607285          5641142
# Montana                  30           903773           906961
# Nebraska                 31          1713820          1719836
# Nevada                   32          2018741          2098399
# New Hampshire            33          1239882          1255517
# New Jersey               34          8430621          8492671
# District of Columbia           659005           670377           681170
# Florida                      19888741         20244914         20612439
# Georgia                      10087231         10199398         10310371
# Hawaii                        1416349          1425157          1428557
# Idaho                         1633532          1652828          1683140
# Illinois                     12867544         12839047         12801539
# Indiana                       6595233          6612768          6633053
# Iowa                          3108030          3121997          3134693
# Kansas                        2899360          2906721          2907289
# Kentucky                      4413057          4424611          4436974
# Louisiana                     4647880          4668960          4681666
# Maine                         1330719          1329453          1331479
# Maryland                      5967295          5994983          6016447
# Massachusetts                 6749911          6784240          6811779
# Michigan                      9915767          9917715          9928300
# Minnesota                     5453109          5482435          5519952
# Mississippi                   2992400          2989390          2988726
# Missouri                      6060930          6076204          6093000
# Montana                       1022867          1032073          1042520
# Nebraska                      1881145          1893765          1907116
# Nevada                        2833013          2883758          2940058
# New Hampshire                 1328743          1330111          1334795
# New Jersey                    8925001          8935421          8944469
# New Mexico                    2083024          2080328          2081015
# New York                     19718515         19747183         19745289
# North Carolina                9934399         10035186         10146788
# North Dakota                   739904           756835           757952
# Ohio                         11594408         11605090         11614373
# Oklahoma                      3877499          3907414          3923561
# Oregon                        3968371          4024634          4093465
# Pennsylvania                 12790565         12791904         12784227
# Rhode Island                  1054480          1055607          1056426
# South Carolina                4828430          4894834          4961119
# South Dakota                   852561           857919           865454
# Tennessee                     6544663          6595056          6651194
# Texas                        26944751         27429639         27862596
# Utah                          2941836          2990632          3051217
# Vermont                        626984           626088           624594
# Virginia                      8317372          8367587          8411808
# Washington                    7054196          7160290          7288000
# West Virginia                 1848514          1841053          1831102
# Wisconsin                     5758377          5767891          5778708
# Wyoming                        583642           586555           585501

# %%
stjoin3.columns
# Out:
# Index(['STATE', 'STNAME', 'POPESTIMATE2000', 'POPESTIMATE2001',
#        'POPESTIMATE2002', 'POPESTIMATE2003', 'POPESTIMATE2004',
#        'POPESTIMATE2005', 'POPESTIMATE2006', 'POPESTIMATE2007',
#        'POPESTIMATE2008', 'POPESTIMATE2009', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'POPESTIMATE2016'],
#       dtype='object')

# %% [markdown]
# Much nicer.  But I really don't like those column names.  Can't we just make them simple years?

# %%
stjoin4 = stjoin3
stjoin4.columns = list(stjoin3.columns[0:2])+list(range(2000,2017))
stjoin4 = stjoin4.set_index('STNAME')
stjoin4.head()
# Out:
#             STATE      2000      2001      2002      2003      2004      2005  \
# STNAME
# Alabama         1   4452173   4467634   4480089   4503491   4530729   4569805
# Alaska          2    627963    633714    642337    648414    659286    666946
# Arizona         4   5160586   5273477   5396255   5510364   5652404   5839077
# Arkansas        5   2678588   2691571   2705927   2724816   2749686   2781097
# California      6  33987977  34479458  34871843  35253159  35574576  35827943
#
#                 2006      2007      2008      2009      2010      2011  \
# STNAME
# Alabama      4628981   4672840   4718206   4757938   4785298   4799918
# Alaska        675302    680300    687455    698895    713985    722713
# Arizona      6029141   6167681   6280362   6343154   6413737   6467163
# Arkansas     2821761   2848650   2874554   2896843   2921606   2939493
# California  36021202  36250311  36604337  36961229  37349363  37676861
#
#                 2012      2013      2014      2015      2016
# STNAME
# Alabama      4815960   4829479   4843214   4853875   4863300
# Alaska        731089    736879    736705    737709    741894
# Arizona      6549634   6624617   6719993   6817565   6931071
# Arkansas     2950685   2958663   2966912   2977853   2988248
# California  38011074  38335203  38680810  38993940  39250017

# %%
stjoin4.to_csv('data/statepop.csv')

# %% [markdown]
# It might also be handy to transpose the data so that the rows become columns and vice versa.  Let's do that and select just a couple of states.

# %%
ST = stjoin4.transpose()
ST[['California','New York']]
# Out:
# STNAME  California  New York
# 2000      33987977  19001780
# 2001      34479458  19082838
# 2002      34871843  19137800
# 2003      35253159  19175939
# 2004      35574576  19171567
# 2005      35827943  19132610
# 2006      36021202  19104631
# 2007      36250311  19132335
# 2008      36604337  19212436
# 2009      36961229  19307066
# 2010      37349363  19392283
# 2011      37676861  19519529
# 2012      38011074  19602769
# 2013      38335203  19673546
# 2014      38680810  19718515
# 2015      38993940  19747183
# 2016      39250017  19745289

# %% [markdown]
# Maybe a quick plot of the population trends in these states?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(ST[['California', 'Texas']])
# Out:
# [<matplotlib.lines.Line2D at 0x121e4e9b0>,
#  <matplotlib.lines.Line2D at 0x121e4ebe0>]

# %% [markdown]
# And for those of you who love your Excel for making charts, since mine is pretty ugly, go for it:

# %%
writer = pd.ExcelWriter('data/state_population.xlsx')
stjoin4.to_excel(writer,'Sheet1')
writer.save()

# %% [markdown]
# ## Data Exploration and Cleaning
#
# **Let's load some crime call events from the Berkeley Police Department and explore those data...  this is an example of having to wrangle some messy, real world data.  It's advanced work that you now can handle in Python!**
#
# For example lets say we want to find out how many vandalism calls there are each day of the week. Let's load some data and figure out how to answer that.
#
# https://data.cityofberkeley.info/Public-Safety/Berkeley-PD-Calls-for-Service/k2nh-s5h5

# %%
calls = pd.read_csv('data/Berkeley_PD_-_Calls_for_Service.csv')
calls.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  17036655            VEHICLE STOLEN  06/24/2017 12:00:00 AM   21:30
# 1  17091623  THEFT MISD. (UNDER $950)  08/14/2017 12:00:00 AM   02:35
# 2  17029390               DISTURBANCE  05/24/2017 12:00:00 AM   10:37
# 3  17044257               DISTURBANCE  07/30/2017 12:00:00 AM   03:56
# 4  17021336             BURGLARY AUTO  04/16/2017 12:00:00 AM   19:00
#
#               CVLEGEND  CVDOW                InDbDate  \
# 0  MOTOR VEHICLE THEFT      6  09/24/2017 03:30:20 AM
# 1              LARCENY      1  09/24/2017 03:30:15 AM
# 2   DISORDERLY CONDUCT      3  09/24/2017 03:30:24 AM
# 3   DISORDERLY CONDUCT      0  09/24/2017 03:30:24 AM
# 4   BURGLARY - VEHICLE      0  09/24/2017 03:30:17 AM
#
#                                       Block_Location  \
# 0  1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1  1200 COLUSA AVE\nBerkeley, CA\n(37.884071, -12...
# 2  2200 MILVIA ST\nBerkeley, CA\n(37.868574, -122...
# 3  ASHBY AVENUE &amp; CLAREMONT AVE\nBerkeley, CA...
# 4  2300 CURTIS ST\nBerkeley, CA\n(37.864897, -122...
#
#                         BLKADDR      City State
# 0                1000 OXFORD ST  Berkeley    CA
# 1               1200 COLUSA AVE  Berkeley    CA
# 2                2200 MILVIA ST  Berkeley    CA
# 3  ASHBY AVENUE & CLAREMONT AVE  Berkeley    CA
# 4                2300 CURTIS ST  Berkeley    CA

# %% [markdown]
# Let's also load a lookup for CVDOW (Day of Week) to the day names

# %%
cvdow = pd.read_csv("data/cvdow.csv")
cvdow
# Out:
#    CVDOW        Day
# 0      0     Sunday
# 1      1     Monday
# 2      2    Tuesday
# 3      3  Wednesday
# 4      4   Thursday
# 5      5     Friday
# 6      6   Saturday

# %% [markdown]
# How many calls are in this dataset?

# %%
len(calls)
# Out:
# 5640

# %% [markdown]
# ### Preliminary observations on the data?
#
# 1. `EVENTDT` -- Contain the incorrect time stamp (all the times are 12:00 am)
# 1. `EVENTTM` -- Contains the time in 24 hour format (What timezone?)
# 1. `InDbDate` -- Appears to be correctly formatted and appears awfully consistent in time.
# 1. **`Block_Location` -- Errr, what a mess!  newline characters, and Geocoordinates all merged!!  Fortunately, this field was "quoted" otherwise we would have had trouble parsing the file. (why?)**
# 1. `BLKADDR` -- This appears to be the address in Block Location.
# 1. `City` and `State` seem redundant given this is supposed to be the city of Berkeley dataset.

# %%
new = pd.merge(calls,cvdow, on='CVDOW', how='inner')
new.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  17036655            VEHICLE STOLEN  06/24/2017 12:00:00 AM   21:30
# 1  17091596  THEFT MISD. (UNDER $950)  08/05/2017 12:00:00 AM   01:15
# 2  17035039       BURGLARY COMMERCIAL  06/17/2017 12:00:00 AM   18:00
# 3  17035224      BURGLARY RESIDENTIAL  06/17/2017 12:00:00 AM   04:00
# 4  17031721                 VANDALISM  06/03/2017 12:00:00 AM   14:25
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0     MOTOR VEHICLE THEFT      6  09/24/2017 03:30:20 AM
# 1                 LARCENY      6  09/24/2017 03:30:15 AM
# 2   BURGLARY - COMMERCIAL      6  09/24/2017 03:30:19 AM
# 3  BURGLARY - RESIDENTIAL      6  09/24/2017 03:30:19 AM
# 4               VANDALISM      6  09/24/2017 03:30:19 AM
#
#                                       Block_Location  \
# 0  1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1  1300 PARKER ST\nBerkeley, CA\n(37.859906, -122...
# 2  2600 DWIGHT WAY\nBerkeley, CA\n(37.86542, -122...
# 3  1300 ACTON ST\nBerkeley, CA\n(37.882294, -122....
# 4  SHATTUCK AVENUE &amp; KITTREDGE ST\nBerkeley, ...
#
#                           BLKADDR      City State       Day
# 0                  1000 OXFORD ST  Berkeley    CA  Saturday
# 1                  1300 PARKER ST  Berkeley    CA  Saturday
# 2                 2600 DWIGHT WAY  Berkeley    CA  Saturday
# 3                   1300 ACTON ST  Berkeley    CA  Saturday
# 4  SHATTUCK AVENUE & KITTREDGE ST  Berkeley    CA  Saturday

# %% [markdown]
# How could we find out how many Vandalism calls happen by Day of the week?

# %%
new['Day'][new['OFFENSE']=='VANDALISM'].value_counts()
# Out:
# Thursday     75
# Friday       72
# Monday       69
# Tuesday      66
# Wednesday    57
# Saturday     56
# Sunday       51
# Name: Day, dtype: int64

# %%
new['Block_Location'].head()
# Out:
# 0    1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1    1300 PARKER ST\nBerkeley, CA\n(37.859906, -122...
# 2    2600 DWIGHT WAY\nBerkeley, CA\n(37.86542, -122...
# 3    1300 ACTON ST\nBerkeley, CA\n(37.882294, -122....
# 4    SHATTUCK AVENUE &amp; KITTREDGE ST\nBerkeley, ...
# Name: Block_Location, dtype: object

# %%
new['Block_Location'][0]
# Out:
# '1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122.268299)'

# %%
new['Block_Location'].str.find('(').head()
# Out:
# 0    28
# 1    28
# 2    29
# 3    27
# 4    48
# Name: Block_Location, dtype: int64

# %%
for label in new.Block_Location.index:
    start=new.Block_Location[label].find('(') + 1
    end= start+9
    new.loc[label,'Lat'] = new.Block_Location[label][start:end].strip(',')

# %%
new.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  17036655            VEHICLE STOLEN  06/24/2017 12:00:00 AM   21:30
# 1  17091596  THEFT MISD. (UNDER $950)  08/05/2017 12:00:00 AM   01:15
# 2  17035039       BURGLARY COMMERCIAL  06/17/2017 12:00:00 AM   18:00
# 3  17035224      BURGLARY RESIDENTIAL  06/17/2017 12:00:00 AM   04:00
# 4  17031721                 VANDALISM  06/03/2017 12:00:00 AM   14:25
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0     MOTOR VEHICLE THEFT      6  09/24/2017 03:30:20 AM
# 1                 LARCENY      6  09/24/2017 03:30:15 AM
# 2   BURGLARY - COMMERCIAL      6  09/24/2017 03:30:19 AM
# 3  BURGLARY - RESIDENTIAL      6  09/24/2017 03:30:19 AM
# 4               VANDALISM      6  09/24/2017 03:30:19 AM
#
#                                       Block_Location  \
# 0  1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1  1300 PARKER ST\nBerkeley, CA\n(37.859906, -122...
# 2  2600 DWIGHT WAY\nBerkeley, CA\n(37.86542, -122...
# 3  1300 ACTON ST\nBerkeley, CA\n(37.882294, -122....
# 4  SHATTUCK AVENUE &amp; KITTREDGE ST\nBerkeley, ...
#
#                           BLKADDR      City State       Day        Lat
# 0                  1000 OXFORD ST  Berkeley    CA  Saturday  37.890716
# 1                  1300 PARKER ST  Berkeley    CA  Saturday  37.859906
# 2                 2600 DWIGHT WAY  Berkeley    CA  Saturday   37.86542
# 3                   1300 ACTON ST  Berkeley    CA  Saturday  37.882294
# 4  SHATTUCK AVENUE & KITTREDGE ST  Berkeley    CA  Saturday  37.868489

# %% [markdown]
# OK, now do this to add a Long column to the dataframe...

# %%
for label in new.Block_Location.index:
    start=new.Block_Location[label].find('-')
    end= new.Block_Location[label].find(')')
    new.loc[label,'Lon'] = new.Block_Location[label][start:end].strip(',')

# %%
new.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  17036655            VEHICLE STOLEN  06/24/2017 12:00:00 AM   21:30
# 1  17091596  THEFT MISD. (UNDER $950)  08/05/2017 12:00:00 AM   01:15
# 2  17035039       BURGLARY COMMERCIAL  06/17/2017 12:00:00 AM   18:00
# 3  17035224      BURGLARY RESIDENTIAL  06/17/2017 12:00:00 AM   04:00
# 4  17031721                 VANDALISM  06/03/2017 12:00:00 AM   14:25
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0     MOTOR VEHICLE THEFT      6  09/24/2017 03:30:20 AM
# 1                 LARCENY      6  09/24/2017 03:30:15 AM
# 2   BURGLARY - COMMERCIAL      6  09/24/2017 03:30:19 AM
# 3  BURGLARY - RESIDENTIAL      6  09/24/2017 03:30:19 AM
# 4               VANDALISM      6  09/24/2017 03:30:19 AM
#
#                                       Block_Location  \
# 0  1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1  1300 PARKER ST\nBerkeley, CA\n(37.859906, -122...
# 2  2600 DWIGHT WAY\nBerkeley, CA\n(37.86542, -122...
# 3  1300 ACTON ST\nBerkeley, CA\n(37.882294, -122....
# 4  SHATTUCK AVENUE &amp; KITTREDGE ST\nBerkeley, ...
#
#                           BLKADDR      City State       Day        Lat  \
# 0                  1000 OXFORD ST  Berkeley    CA  Saturday  37.890716
# 1                  1300 PARKER ST  Berkeley    CA  Saturday  37.859906
# 2                 2600 DWIGHT WAY  Berkeley    CA  Saturday   37.86542
# 3                   1300 ACTON ST  Berkeley    CA  Saturday  37.882294
# 4  SHATTUCK AVENUE & KITTREDGE ST  Berkeley    CA  Saturday  37.868489
#
#            Lon
# 0  -122.268299
# 1  -122.284931
# 2   -122.25618
# 3  -122.284835
# 4   -122.26795

# %% [markdown]
# How could you check whether city and state are all redundant (since this is supposed to be City of Berkeley data)?

# %%
new['City'].value_counts()
# Out:
# Berkeley    5640
# Name: City, dtype: int64

# %%
new['State'].value_counts()
# Out:
# CA    5640
# Name: State, dtype: int64

# %% [markdown]
# If they are duplicated, delete those columns

# %%
# This approach enables dropping both columns at once, and does not raise an error if you run it more than once
new.drop(['City', 'State'],axis=1, inplace=True, errors='ignore')
new.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  17036655            VEHICLE STOLEN  06/24/2017 12:00:00 AM   21:30
# 1  17091596  THEFT MISD. (UNDER $950)  08/05/2017 12:00:00 AM   01:15
# 2  17035039       BURGLARY COMMERCIAL  06/17/2017 12:00:00 AM   18:00
# 3  17035224      BURGLARY RESIDENTIAL  06/17/2017 12:00:00 AM   04:00
# 4  17031721                 VANDALISM  06/03/2017 12:00:00 AM   14:25
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0     MOTOR VEHICLE THEFT      6  09/24/2017 03:30:20 AM
# 1                 LARCENY      6  09/24/2017 03:30:15 AM
# 2   BURGLARY - COMMERCIAL      6  09/24/2017 03:30:19 AM
# 3  BURGLARY - RESIDENTIAL      6  09/24/2017 03:30:19 AM
# 4               VANDALISM      6  09/24/2017 03:30:19 AM
#
#                                       Block_Location  \
# 0  1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1  1300 PARKER ST\nBerkeley, CA\n(37.859906, -122...
# 2  2600 DWIGHT WAY\nBerkeley, CA\n(37.86542, -122...
# 3  1300 ACTON ST\nBerkeley, CA\n(37.882294, -122....
# 4  SHATTUCK AVENUE &amp; KITTREDGE ST\nBerkeley, ...
#
#                           BLKADDR       Day        Lat          Lon
# 0                  1000 OXFORD ST  Saturday  37.890716  -122.268299
# 1                  1300 PARKER ST  Saturday  37.859906  -122.284931
# 2                 2600 DWIGHT WAY  Saturday   37.86542   -122.25618
# 3                   1300 ACTON ST  Saturday  37.882294  -122.284835
# 4  SHATTUCK AVENUE & KITTREDGE ST  Saturday  37.868489   -122.26795

# %% [markdown]
# Let's fix the date time to be able to parse the dates and work with them. Pandas has very helpful functionality using a datetime datatype.

# %%
#new['EVENTDT'].to_datetime()
new['DATE'] = pd.to_datetime(new['EVENTDT'])
new['MONTH'] = new['DATE'].dt.month

# %%
new.head()
# Out:
#      CASENO                   OFFENSE                 EVENTDT EVENTTM  \
# 0  17036655            VEHICLE STOLEN  06/24/2017 12:00:00 AM   21:30
# 1  17091596  THEFT MISD. (UNDER $950)  08/05/2017 12:00:00 AM   01:15
# 2  17035039       BURGLARY COMMERCIAL  06/17/2017 12:00:00 AM   18:00
# 3  17035224      BURGLARY RESIDENTIAL  06/17/2017 12:00:00 AM   04:00
# 4  17031721                 VANDALISM  06/03/2017 12:00:00 AM   14:25
#
#                  CVLEGEND  CVDOW                InDbDate  \
# 0     MOTOR VEHICLE THEFT      6  09/24/2017 03:30:20 AM
# 1                 LARCENY      6  09/24/2017 03:30:15 AM
# 2   BURGLARY - COMMERCIAL      6  09/24/2017 03:30:19 AM
# 3  BURGLARY - RESIDENTIAL      6  09/24/2017 03:30:19 AM
# 4               VANDALISM      6  09/24/2017 03:30:19 AM
#
#                                       Block_Location  \
# 0  1000 OXFORD ST\nBerkeley, CA\n(37.890716, -122...
# 1  1300 PARKER ST\nBerkeley, CA\n(37.859906, -122...
# 2  2600 DWIGHT WAY\nBerkeley, CA\n(37.86542, -122...
# 3  1300 ACTON ST\nBerkeley, CA\n(37.882294, -122....
# 4  SHATTUCK AVENUE &amp; KITTREDGE ST\nBerkeley, ...
#
#                           BLKADDR       Day        Lat          Lon  \
# 0                  1000 OXFORD ST  Saturday  37.890716  -122.268299
# 1                  1300 PARKER ST  Saturday  37.859906  -122.284931
# 2                 2600 DWIGHT WAY  Saturday   37.86542   -122.25618
# 3                   1300 ACTON ST  Saturday  37.882294  -122.284835
# 4  SHATTUCK AVENUE & KITTREDGE ST  Saturday  37.868489   -122.26795
#
#         DATE  MONTH
# 0 2017-06-24      6
# 1 2017-08-05      8
# 2 2017-06-17      6
# 3 2017-06-17      6
# 4 2017-06-03      6

# %%
new.to_csv('data/calls.csv')
